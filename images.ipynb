# %%
import os

# %%
#Kernel used for downloading images from Kaggle
if os.path.isdir("PetImages"):
    print("All is well!")
elif not os.path.isfile("kagglecatsanddogs_5340.zip"):
    # !curl -O https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
elif os.path.isfile("kagglecatsanddogs_5340.zip") and not os.path.isdir("PetImages"):
    # !unzip -q kagglecatsanddogs_5340.zip
    # !ls
# Out:
# All is well!

# %%
#deleting corrupted images
num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = b"JFIF" in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            os.remove(fpath)

print(f"Deleted {num_skipped} images.")
# Out:
# Deleted 1578 images.
